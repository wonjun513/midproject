# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/data/temp_2017_2022.csv", encoding = 'cp949')
df.shape
# Out:
# (6844, 12)

# %%
df
# Out:
#        지점 지점명      일시    년도    월  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  \
# 0      90  속초  17-Jan  2017   1월       0.8         5.0        -3.3      11.3
# 1      90  속초  17-Feb  2017   2월       3.0         7.5        -1.7      14.7
# 2      90  속초  17-Mar  2017   3월       7.0        11.4         2.6      18.5
# 3      90  속초  17-Apr  2017   4월      14.8        20.1         9.8      30.8
# 4      90  속초  17-May  2017   5월      18.7        23.8        13.8      34.3
# ...   ...  ..     ...   ...  ...       ...         ...         ...       ...
# 6839  295  남해  22-Aug  2022   8월      26.3        29.7        23.3      34.1
# 6840  295  남해  22-Sep  2022   9월      22.1        26.3        18.9      32.6
# 6841  295  남해  22-Oct  2022  10월      16.3        21.4        12.2      28.7
# 6842  295  남해  22-Nov  2022  11월      12.1        17.7         7.4      21.4
# 6843  295  남해  22-Dec  2022  12월       2.5         6.8        -1.5      11.8
#
# ...

# %%
df.isnull()
# Out:
#          지점    지점명     일시     년도      월  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  \
# 0     False  False  False  False  False     False       False       False
# 1     False  False  False  False  False     False       False       False
# 2     False  False  False  False  False     False       False       False
# 3     False  False  False  False  False     False       False       False
# 4     False  False  False  False  False     False       False       False
# ...     ...    ...    ...    ...    ...       ...         ...         ...
# 6839  False  False  False  False  False     False       False       False
# 6840  False  False  False  False  False     False       False       False
# 6841  False  False  False  False  False     False       False       False
# 6842  False  False  False  False  False     False       False       False
# 6843  False  False  False  False  False     False       False       False
#
#       최고기온(°C)  최저기온(°C)  최고기온 나타난날(yyyymmdd)  최저기온 나타난날(yyyymmdd)
# ...

# %%
temp_spot = df[(df['지점명'] == '서울')]
temp_spot
# Out:
#       지점 지점명      일시    년도    월  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  \
# 792  108  서울  17-Jan  2017   1월      -1.8         2.9        -5.8      11.4
# 793  108  서울  17-Feb  2017   2월      -0.2         4.8        -4.7      12.3
# 794  108  서울  17-Mar  2017   3월       6.3        12.3         1.7      18.9
# 795  108  서울  17-Apr  2017   4월      13.9        20.0         9.1      27.8
# 796  108  서울  17-May  2017   5월      19.5        25.4        14.4      30.3
# ..   ...  ..     ...   ...  ...       ...         ...         ...       ...
# 859  108  서울  22-Aug  2022   8월      25.7        28.9        23.1      32.9
# 860  108  서울  22-Sep  2022   9월      22.4        27.2        18.2      32.5
# 861  108  서울  22-Oct  2022  10월      14.6        19.7        10.3      27.6
# 862  108  서울  22-Nov  2022  11월      10.0        15.4         5.6      22.1
# 863  108  서울  22-Dec  2022  12월      -2.8         1.7        -6.6      10.2
#
#      최저기온(°C)  최고기온 나타난날(yyyymmdd)  최저기온 나타난날(yyyymmdd)
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.xlabel = "날짜"
plt.ylabel = "온도"
plt.plot(temp_spot['일시'], temp_spot['평균기온(°C)'])
plt.show()

# %%
temp_year = df[(df['년도'] == 2017)]
temp_year
# Out:
#        지점 지점명      일시    년도    월  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  \
# 0      90  속초  17-Jan  2017   1월       0.8         5.0        -3.3      11.3
# 1      90  속초  17-Feb  2017   2월       3.0         7.5        -1.7      14.7
# 2      90  속초  17-Mar  2017   3월       7.0        11.4         2.6      18.5
# 3      90  속초  17-Apr  2017   4월      14.8        20.1         9.8      30.8
# 4      90  속초  17-May  2017   5월      18.7        23.8        13.8      34.3
# ...   ...  ..     ...   ...  ...       ...         ...         ...       ...
# 6779  295  남해  17-Aug  2017   8월      27.1        31.7        23.7      36.9
# 6780  295  남해  17-Sep  2017   9월      21.9        27.0        17.9      29.7
# 6781  295  남해  17-Oct  2017  10월      17.2        22.0        13.8      28.6
# 6782  295  남해  17-Nov  2017  11월       9.9        15.6         4.8      22.6
# 6783  295  남해  17-Dec  2017  12월       2.6         7.6        -2.3      13.0
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.xlabel = "날짜"
plt.ylabel = "온도"
plt.plot(temp_year['일시'], temp_year['평균기온(°C)'])
plt.show()
