# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/data/산업분류별 월별 전력사용량_2017_2022.csv")
df
# Out:
#            년월      시구            시군구                계약구분   고객호수(호)  \
# 0      201701  전체(시도)  전체(시 / 군 / 구)     가구내고용,미분류자가소비생산      528
# 1      201701  전체(시도)  전체(시 / 군 / 구)                건설업    70,529
# 2      201701  전체(시도)  전체(시 / 군 / 구)  공공행정, 국방 및 사회보장 행정   34,768
# 3      201701  전체(시도)  전체(시 / 군 / 구)                 광업     4,614
# 4      201701  전체(시도)  전체(시 / 군 / 구)             교육 서비스업   69,866
# ...       ...     ...            ...                 ...       ...
# 28303  202212    충청북도             전체                제조업    13,495
# 28304  202212    충청북도             전체     출판영상,방송통신정보서비스업   10,528
# 28305  202212    충청북도             전체      하수폐기처리원료재생환경복원    2,014
# 28306  202212    충청북도             전체     협회단체,수리기타개인서비스업    9,077
# 28307  202212    충청북도             전체                  합계  305,476
#
#              사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0            571,710        86,427,025         151.2
# 1        367,547,850    49,248,531,866         134.0
# ...

# %%
Eleuse_spot = df[(df['시구'] == '충청북도')]
Eleuse_spot
# Out:
#            년월    시구 시군구                계약구분   고객호수(호)        사용량(kWh)  \
# 478    201701  충청북도  전체     가구내고용,미분류자가소비생산        7           4,729
# 479    201701  충청북도  전체                건설업     3,779      16,297,545
# 480    201701  충청북도  전체  공공행정, 국방 및 사회보장 행정    1,684      27,109,695
# 481    201701  충청북도  전체                 광업       176      10,833,875
# 482    201701  충청북도  전체             교육 서비스업    2,942      43,574,898
# ...       ...   ...  ..                 ...       ...             ...
# 28303  202212  충청북도  전체                제조업    13,495   1,624,994,320
# 28304  202212  충청북도  전체     출판영상,방송통신정보서비스업   10,528      18,489,918
# 28305  202212  충청북도  전체      하수폐기처리원료재생환경복원    2,014      27,704,884
# 28306  202212  충청북도  전체     협회단체,수리기타개인서비스업    9,077      19,703,984
# 28307  202212  충청북도  전체                  합계  305,476   2,220,188,169
#
#                 전기요금(원) 평균판매단가(원/kWh)
# 478            412,406          87.2
# 479      2,160,388,629         132.6
# ...

# %%
Eleuse_kind = df[(df['계약구분'] == '제조업')]
Eleuse_kind
# Out:
#            년월       시구            시군구 계약구분   고객호수(호)         사용량(kWh)  \
# 2368   201707   전체(시도)  전체(시 / 군 / 구)  제조업  332,067   22,128,019,531
# 2389   201708   전체(시도)  전체(시 / 군 / 구)  제조업  333,072   21,708,908,958
# 2410   201709   전체(시도)  전체(시 / 군 / 구)  제조업  333,762   21,727,256,670
# 2431   201710   전체(시도)  전체(시 / 군 / 구)  제조업  334,278   20,408,028,073
# 2452   201711   전체(시도)  전체(시 / 군 / 구)  제조업  335,177   21,371,666,629
# ...       ...      ...            ...  ...       ...              ...
# 21647  202107     전라남도             전체  제조업   13,270    1,787,401,259
# 21669  202107     전라북도             전체  제조업   11,653      965,768,623
# 21691  202107  제주특별자치도             전체  제조업    1,951       27,134,061
# 21713  202107     충청남도             전체  제조업   17,762    3,021,995,628
# 21734  202107     충청북도             전체  제조업   13,281    1,614,994,311
#
#                   전기요금(원) 평균판매단가(원/kWh)
# 2368   2,582,842,897,836         116.7
# 2389   2,542,158,986,921         117.1
# ...

# %%
plt.figure(figsize=(10, 6))
plt.xlabel = "시구"
plt.ylabel = "사용량(kWh)"
plt.plot(Eleuse_kind['시구'], Eleuse_kind['사용량(kWh)'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
